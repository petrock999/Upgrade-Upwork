# %%
# %pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.0-py2.py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 13.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->bertopic)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.35.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu121)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, umap-learn
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039296 sha256=a6cb89985f97064488b8c0ee7036e171aecfe8f922453ec2c44f38555df41e37
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=c744f82e588fb400ff2a2ac12400837a048b9448de795ca65eb59c1f5fde1665
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built hdbscan umap-learn
# Installing collected packages: cython, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.8
#     Uninstalling Cython-3.0.8:
#       Successfully uninstalled Cython-3.0.8
# Successfully installed bertopic-0.16.0 cython-0.29.37 hdbscan-0.8.33 pynndescent-0.5.11 sentence-transformers-2.3.1 umap-learn-0.5.5

# %%
from bertopic import BERTopic

# %%
import json
import pandas as pd

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer_model = CountVectorizer(stop_words="english")

# %%
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2")

# %%
topic_mode_no_vec = BERTopic(embedding_model="all-MiniLM-L6-v2")

# %%
topic_model_yes_vec = BERTopic(embedding_model="all-MiniLM-L6-v2", vectorizer_model=vectorizer_model)

# %%
full_df = pd.read_csv("/content/drive/MyDrive/!AAA/full.csv")

# %%
full_df_index = full_df["Category_1"].value_counts().head(20).index

# %%
full_df_index
# Out:
# Index(['Web Development', 'Social Media Marketing', 'Marketing Strategy',
#        '3D Modeling', 'Email Marketing', 'Mobile App Development', '3D Design',
#        'Market Research', '3D Rendering', 'Android App Development',
#        '3D Animation', 'Python', 'Data Scraping', 'Data Analysis',
#        'Search Engine Marketing', 'Sales & Marketing', 'Influencer Marketing',
#        'Data Science', 'B2B Marketing', 'Lead Generation'],
#       dtype='object')

# %%
for index in full_df_index:
    for ex_level in full_df[full_df["Category_1"] == index]["EX_level_demand"].unique():

        print(ex_level, index)
    print("--")
# Out:
# Expert Web Development
# Intermediate Web Development
# Entry level Web Development
# --
# Intermediate Social Media Marketing
# Expert Social Media Marketing
# Entry level Social Media Marketing
# --
# Intermediate Marketing Strategy
# Expert Marketing Strategy
# Entry level Marketing Strategy
# --
# Expert 3D Modeling
# Entry level 3D Modeling
# Intermediate 3D Modeling
# --
# Expert Email Marketing
# Intermediate Email Marketing
# Entry level Email Marketing
# --
# Intermediate Mobile App Development
# Expert Mobile App Development
# Entry level Mobile App Development
# --
# Expert 3D Design
# Intermediate 3D Design
# Entry level 3D Design
# --
# Intermediate Market Research
# Expert Market Research
# Entry level Market Research
# --
# Intermediate 3D Rendering
# Expert 3D Rendering
# Entry level 3D Rendering
# --
# Intermediate Android App Development
# Entry level Android App Development
# Expert Android App Development
# --
# Intermediate 3D Animation
# Expert 3D Animation
# Entry level 3D Animation
# --
# Intermediate Python
# Entry level Python
# Expert Python
# --
# Intermediate Data Scraping
# Entry level Data Scraping
# Expert Data Scraping
# --
# Expert Data Analysis
# Intermediate Data Analysis
# Entry level Data Analysis
# --
# Expert Search Engine Marketing
# Intermediate Search Engine Marketing
# Entry level Search Engine Marketing
# --
# Intermediate Sales & Marketing
# Entry level Sales & Marketing
# Expert Sales & Marketing
# --
# Expert Influencer Marketing
# Intermediate Influencer Marketing
# Entry level Influencer Marketing
# --
# Expert Data Science
# Intermediate Data Science
# Entry level Data Science
# --
# Entry level B2B Marketing
# Intermediate B2B Marketing
# Expert B2B Marketing
# --
# Entry level Lead Generation
# Expert Lead Generation
# Intermediate Lead Generation
# --

# %%
for index in full_df_index:
    for ex_level in full_df[full_df["Category_1"] == index]["EX_level_demand"].unique():
        print("-----------")
        print(index, ex_level)
        print("-----------")
        condition1 = full_df["Category_1"] == index
        condition2 = full_df["EX_level_demand"] == ex_level
        print(full_df[condition1 & condition2]["Description"])
# Out:
# -----------
# Web Development Expert
# -----------
# 820      About the company:\n\nWe are a cutting-edge AI...
# 1357     I need a simple website built on AWS. Most imp...
# 1628     I need a beautiful, fast and smooth website bu...
# 1692     I would like a long-term working relationship ...
# 1936     Prototype, Design & Develop an E-Learning Plat...
#                                ...
# 26318    hi there\nim creating a shopify tracking tool,...
# 43380    Looking for a Genius Fixer -- not SEO\n\nAmeri...
# 44503    I am looking to create a university email and ...
# 45548    Real Estate Bidders is a real estate investmen...
# 45727    My website URL is blocked my Meta on Facebook,...
# Name: Description, Length: 2330, dtype: object
# -----------
# Web Development Intermediate
# -----------
# 1052     We are a startup that is building education pr...
# 1257     Build a web tool that allows users to create a...
# 1318     We are seeking an experienced Bubble (No Code)...
# 1612     We want to create a simple platform where the ...
# 1632     I need a beautiful, fast and smooth website bu...
#                                ...
# 36471    Need someone who can create an Instagram busin...
# 37933    Job Overview:\nWe are looking for a talented f...
# 38969    Seeking web developer to build new site and mi...
# 45174    i need email marketing system same like refere...
# 46432    I am looking for a website similar to https://...
# Name: Description, Length: 3231, dtype: object
# -----------
# Web Development Entry level
# -----------
# 8387     Full-stack developer needed for a full-time/pa...
# 8390     I am looking for a person who is familiar with...
# 8454     Job Summary:\nWe are seeking a highly motivate...
# 8456     in need of a serious trusted and reliable pers...
# 8580     Understanding of sea freight Industry includin...
#                                ...
# 26107    Need help with the current website - https://s...
# 26114    need to have existing premade template customi...
# 26206    Consistently generate code that can be easily ...
# 26210    Hello! I am creating a new website to house my...
# 45902    We are using Circle.so as our platform for com...
# Name: Description, Length: 545, dtype: object
# -----------
# Social Media Marketing Intermediate
# -----------
# 2589     Good day.\n\nWe are a RV rental company (Motor...
# 3289     For affiliate marketing from ClickBank, CJ, an...
# 6321     Hello, I am looking to create 2 ads campaign o...
# 13779    Need a large number of dummy accounts to authe...
# 18154    I am Uk based Company Employee. We have lot of...
#                                ...
# 47799                                                Hello
# 47811    Job would consist of optimizing our social med...
# 47818    We are looking for an ad manager to set up Met...
# 47824    I'd like for someone to manage my social media...
# 47839    Hello! we are looking for a digital marketer a...
# Name: Description, Length: 2391, dtype: object
# -----------
# Social Media Marketing Expert
# -----------
# 13101    I need a minor modification to the product pag...
# 26344    Arrowwmedia advertising alchemist \n\n\n\nJob ...
# 26350    Help me manage my social media content on Link...
# 26358    I'm looking for someone to manage 2 to 3 socia...
# 26380    We run an E-commerce Agency that builds custom...
#                                ...
# 47767    We are an early-stage Startup company. Our Ins...
# 47788    I run a social media marketing agency, and we ...
# 47790    Setup a campaign on LinkedIn to target page fo...
# 47801    Please don't apply if you don't have any SMM e...
# 47829    We are looking for an experienced and creative...
# Name: Description, Length: 1514, dtype: object
# -----------
# Social Media Marketing Entry level
# -----------
# 26343    Stay up-to-date on existing and emerging digit...
# 26346    Formulate, organize and develop marketing acti...
# 26352    We need a well organized person, you will be c...
# 26390    Help setting my church up for Google grant. Yo...
# 26399    Hello Colleges! \n\nFor our Dropshipping busin...
#                                ...
# 47685    Basically assist with  social media (mostly yo...
# 47692    Hi! 💗\n\nAre you interested in female empowerm...
# 47759    I am looking to purchase US-based verified Lin...
# 47825    Looking for VA For Digital advertising agency,...
# 47845    We are searching for someone who could help us...
# Name: Description, Length: 571, dtype: object
# -----------
# Marketing Strategy Intermediate
# -----------
# 4262     "Transform Your Business Dreams into Reality w...
# 26386    We are looking for an experienced marketing sp...
# 26441    Our IT product infatica.io, a sophisticated so...
# 26450    Looking to start an Etsy store to sell some of...
# 26538    As a [Insert Job Title], you will be responsib...
#                                ...
# 47600    We are Keyturn, a startup that helps investors...
# 47614    We're looking for a detailed analysis of the f...
# 47646    We are an emerging company in marketing & web ...
# 47766    Hello, we are looking to a hire a full time sa...
# 47776    I am writing to you because of the talent I se...
# Name: Description, Length: 738, dtype: object
# -----------
# Marketing Strategy Expert
# -----------
# 9033     We are looking for a talented marketing expert...
# 12087    We are looking for an experienced and very con...
# 25726    A Marketing Expert is responsible for promotin...
# 26331    I am the owner of an online herbalist store an...
# 26335    Digital Media Marketing is needed by an active...
#                                ...
# 47814    We are looking for a BIPOC womxn (cis, non-cis...
# 47815    Hi! We are a beauty clinic & academy based in ...
# 47832    \nWe are a nicotine pouch retailer in Europe a...
# 47833    Job Classification: Full-time\n\nThis is your ...
# 47837    Hi\n\nOur current website is compromised \nhtt...
# Name: Description, Length: 664, dtype: object
# -----------
# Marketing Strategy Entry level
# -----------
# 26342    Ensure the company is communicating the right ...
# 26345    Community Management: Manage and create conten...
# 26487    We are A luxury real estate company trying to ...
# 26704    We need a well organized person, you will be c...
# 26726    We are looking for an experienced Program Mana...
#                                ...
# 46718    Hi ! \n\nI’m a new social media marketing mana...
# 46900    I am looking to increase the views and read co...
# 47137    Assist in the design and implementation of com...
# 47732    Hi there\n\nI own an marketing agency and I ne...
# 47782    Would like to help to launch any product,well ...
# Name: Description, Length: 177, dtype: object
# -----------
# 3D Modeling Expert
# -----------
# 4010     This person needs to have deep experience codi...
# 4036     We have a medical device design in Solidworks ...
# 4048     Architectural and Design Rendering of cabinets...
# 4049     This is a job for render and delivery of image...
# 4052     We have a 4 bed 3 bath house with basement hou...
#                                ...
# 8322     I am looking for a single low polygon Stylized...
# 8332     An independent game studio is looking for a 3D...
# 8337     Our brand new double storey house need to rede...
# 8353     Recent remodel has added approx 100 sq feet to...
# 10205    Hi,\n\nA detailed description will be given at...
# Name: Description, Length: 335, dtype: object
# -----------
# 3D Modeling Entry level
# -----------
# 4032    I need stylized house in blender. Textures in ...
# 4059    Our architect has provided us plans for a new ...
# 4139    Graphic designer needed to insert a new constr...
# 4281    We're looking for someone who can create relie...
# 4316    I would like to have a 3D model/rendering of t...
#                               ...
# 8017    I need a quick rendering made of a female. I k...
# 8035    Create 5 Video Tutorials using an emulator for...
# 8063    I am looking for someone who will make a 3D dr...
# 8081    House needs to be modelled in Bimx or similare...
# 8288    A 3D modeling interior of a living room is nee...
# Name: Description, Length: 82, dtype: object
# -----------
# 3D Modeling Intermediate
# -----------
# 4033     I need a 3D model based on 150 aligned images ...
# 4035     CAD designer to create a 3D model of a residen...
# 4042     I am looking for an experienced Interior Desig...
# 4047     Please make a 3D Visualization of the product ...
# 4062     I am seeking to do a preliminary 3-D design of...
#                                ...
# 8338     The goal is to design a electromechanical syst...
# 8345     Kya aap trading karna chahte hai…..par accurac...
# 8348     Smart iot locker works with our proprietary so...
# 18052    hello. I'm looking to have a whole fishing mec...
# 18402    We are looking for quotes from contractors to ...
# Name: Description, Length: 705, dtype: object
# -----------
# Email Marketing Expert
# -----------
# 767      Seeking somebody with Convertkit experience & ...
# 14426    Description: We are seeking an experienced dev...
# 20234    hello i will like to invite you as regards to ...
# 26336    Hello We are looking for an Expert Email Marke...
# 26396    I am looking for an individual who can speak, ...
#                                ...
# 47509    Mailchimp Email Marketing\n\n-New Design Layou...
# 47666    We're a b2b sales company providing financing ...
# 47679    Hello, I am an executive recruiter in the life...
# 47684    I'm a content manager for a startup tech compa...
# 47842    Set up email accounts and an email system (gma...
# Name: Description, Length: 406, dtype: object
# -----------
# Email Marketing Intermediate
# -----------
# 26351    Experienced Email Blaster needed\nWe need to b...
# 26370    Mattress Mars Orlando Florida \n\nWe would lik...
# 26421    The video ad features empowering and motivatio...
# 26442    Hi everyone! I'm looking for a virtual assista...
# 26504    We are a Website/SMMA business looking to hire...
#                                ...
# 47763    We are a team of freelancers specializing in R...
# 47793    AF1-Media a leading social media marketing age...
# 47805    We are in need of a LinkedIn Sales Navigator E...
# 47823    Med spa Welcome series and 5 monthly emails sh...
# 47834    We are looking for someone to manage campaigns...
# Name: Description, Length: 602, dtype: object
# -----------
# Email Marketing Entry level
# -----------
# 26907    the task is to link Markate, a business manage...
# 27061    Hello there!\nI need many outreacher for our s...
# 27378    Needing appointment setters for my agency will...
# 27407    Needing appointment setters for my agency will...
# 28082    We need to set up sms, whatsapp and email mark...
#                                ...
# 46484    We are looking for an energetic and proactive ...
# 46536    Wholesale sales agency in the fashion and outd...
# 46539    I need a content creator to take 10 videos tha...
# 46991    4 months of Marketing Work for \n1) a Property...
# 47028    Job Title: Freelance Lead Generation Specialis...
# Name: Description, Length: 88, dtype: object
# -----------
# Mobile App Development Intermediate
# -----------
# 3230     A simple chat app that talks to a language mod...
# 3497     A simple chat app that talks to a language mod...
# 8378     Hi, \n\nI want an application in which user ca...
# 8430     To have an app based on the UI/UX of Unifi by ...
# 8445     The organization I create for would like to pa...
#                                ...
# 26191    I'm looking for someone to build me a very cle...
# 26194    We are seeking an intermediate or higher skill...
# 26207    The application is an application that connect...
# 26226    i want full working taxi booking app with sepe...
# 37446    We will building a database of our Partners th...
# Name: Description, Length: 506, dtype: object
# -----------
# Mobile App Development Expert
# -----------
# 3280     We are looking for an experienced developer to...
# 8376     I would like you to develop an app for me that...
# 8407     Want to build an app that can help who are in ...
# 8438     Good morning to all the devs team!\n\nI am loo...
# 8468     We're seeking a mobile software architect to h...
#                                ...
# 25991    Dear all, \n\nI would like to develop a apps s...
# 26034    I need a Flutter developer to significantly im...
# 26070    Job Description:\n\nApp Description: Built in ...
# 26200    We are looking for a senior-level full-stack f...
# 26306    We need a mobile app developer that can develo...
# Name: Description, Length: 306, dtype: object
# -----------
# Mobile App Development Entry level
# -----------
# 8548     I have 20 apps per month those need to be publ...
# 8698     Hi,\nMy name is Alex Mazurkiewicz. I have an i...
# 8877     Do you have a react native app? I am looking f...
# 9135     We Have an android apps to upload on google pl...
# 9199     Responsibilities\n\nAs part of our mobile apps...
#                                ...
# 25632    - Need an Publisher for Publishing My Android ...
# 25633    - Need an Publisher for Publishing My Android ...
# 25798    Hello upload our app on your google play conso...
# 26178    I have a simple card game based program alread...
# 26198    I have a small team of field workers. I requir...
# Name: Description, Length: 91, dtype: object
# -----------
# 3D Design Expert
# -----------
# 4028    Looking for a 3D designer to make my jewellery...
# 4116    I want a plan of a house, I have to build this...
# 4141    Looking for an interior designer for a Europea...
# 4174    Attention Interior Designers! We're looking fo...
# 4212    Hello I require a layout and interior design o...
#                               ...
# 8261    We are seeking an experienced and highly skill...
# 8265    Hey Talents, \n\nI hope you are doing great.\n...
# 8304    I need this outdoor space designed for a clien...
# 8310    We are a boiler company, looking for the membr...
# 8331    Have the basic knowledge in AutoCAD, UGNX, Cat...
# Name: Description, Length: 223, dtype: object
# -----------
# 3D Design Intermediate
# -----------
# 4034    I would like to take minimum period of time to...
# 4039    We seek a organized and detail-oriented Interi...
# 4040    Hi, I require a detailed design drawing with s...
# 4055    Canadian based jewelry designer looking for an...
# 4060    Looking to accessorize our new patio pavilion ...
#                               ...
# 8295    Looking for someone to work with a growing Int...
# 8334    2 Bed Room, 2 Living Spaces, 1 Kitchen, 800 Sq...
# 8336    I need a person who create on best design and ...
# 8349    Looking for an experienced urban designer to w...
# 8350    We are looking for a talent to help realize th...
# Name: Description, Length: 473, dtype: object
# -----------
# 3D Design Entry level
# -----------
# 4045    I am looking for a fashion designer who can cr...
# 4183    Looking for someone to help me to sketch 2 wal...
# 4184    Looking for an intial design for an eSports ar...
# 4187    Im looking to bring on an entry level key play...
# 4201    We need to re-do the exterior of our home incl...
#                               ...
# 7935    Looking for a CAD designer to draw steel fence...
# 7966    We have 2 floors private house and are searchi...
# 8255    Grading and drainage design (possible utility ...
# 8306    We need  experience joinery draftsman who is p...
# 8318    2 bedroom flat interior 3d design rendering to...
# Name: Description, Length: 62, dtype: object
# -----------
# Market Research Intermediate
# -----------
# 404      At MahaDAO, we are looking for a research anal...
# 17791    We are looking for the following types of beha...
# 17932    I have a No-code Web/App development agency, b...
# 26491    Create a comparison of market place offerings ...
# 26532    As a Sales Professional for Air Purifiers, you...
#                                ...
# 47592    Detailed questionnaire will be provided with c...
# 47628    Small government contractor needs an assistant...
# 47726    I'm looking for someone to go through this pro...
# 47731    MUST HAVE PRIOR EXPERIENCE WRITING SBA BUSINES...
# 47735    I need to get a list of digital marketing agen...
# Name: Description, Length: 368, dtype: object
# -----------
# Market Research Expert
# -----------
# 803      Research and create a confidential executive s...
# 26367    I need leads specifically for companies that d...
# 26540    Ongoing help creating SEO-optimized, well rese...
# 26554    Looking for decision makers leads in Gaming in...
# 26557    B2B Email Leads\n\nFinance Director and Decisi...
#                                ...
# 47316    I have a LinkedIn account and using Sales Navi...
# 47596    Thank you for taking time out of your busy sch...
# 47611    Unsure of how to structure the payment of this...
# 47695    Looking for someone to create a list of Canada...
# 47734    Hello Everyone,\n\nWe are seeking a skilled Le...
# Name: Description, Length: 225, dtype: object
# -----------
# Market Research Entry level
# -----------
# 26762    Project Manager Cum Bidder for Submitting Prop...
# 26899    Cold call for a small agency that is looking t...
# 27004    We have lots of women bag and we need to find ...
# 27331    Looking for a current list of businesses in Te...
# 27925    I need someone to use LinkedIn's Sales Navigat...
#                                ...
# 47082    Looking for a lead list of product manufacture...
# 47109    Hi,\n\nThank you in advance for applying to th...
# 47233    Responsible for multiple data management activ...
# 47257    Need help searching the internet for laborator...
# 47268    Looking for a lead list of product manufacture...
# Name: Description, Length: 107, dtype: object
# -----------
# 3D Rendering Intermediate
# -----------
# 4031     Need a 3D character UE5 skeleton for unreal en...
# 4037     Hello, There i'm in the process of launching a...
# 4051     I have a concept to create a cast metal mechan...
# 4071     Seeking a skilled designer for new home constr...
# 4074     Looking for someone to design a home plan for ...
#                                ...
# 8319     I am looking for a 3D CAD to help design a sma...
# 8327     Create plans for home starting with basic layo...
# 8335     hi am looking to renovate existing burger shop...
# 8351     Turn-based combat NFT game, in the metaverse. ...
# 17050    I have a 3D online tool that we developed for ...
# Name: Description, Length: 454, dtype: object
# -----------
# 3D Rendering Expert
# -----------
# 4044    Need to create cads for our custom apparel cat...
# 4067    Need to create cads for our custom apparel cat...
# 4093    Hello there,\n\nWe are looking for an engineer...
# 4109    We are seeking a talented and experienced 3D r...
# 4127    Hi everyone, we need someone to create 3D mock...
#                               ...
# 8254    Our team is looking to hire someone that can u...
# 8290    We’re looking for solid works designer\n3D mod...
# 8326    Summary:\nProduce designs that are unique and ...
# 8328    We are looking to have an architectural landsc...
# 8341    Hello, I am looking for someone who can create...
# Name: Description, Length: 195, dtype: object
# -----------
# 3D Rendering Entry level
# -----------
# 4198    I sell tile products and I need them to be ren...
# 4231    Create a custom art filter. Will include a tak...
# 4258    Already have house plans. Just need the exteri...
# 4379    Need plans to submit to the city for Improving...
# 4382    I need a Floorplan, Elevations and a 3D Iso vi...
# 4405    Looking to have a 3D rendering done of my kitc...
# 4407    Building a house and looking for a 3D Render t...
# 4440    Kitchen renderings for a client. I do 3d visua...
# 4589    We need an Unreal Engine specialist who will s...
# 4612    I need to make 3 images for my 2 old office ro...
# 4626    Need to have a 3D file where we can take diffe...
# 4668    Goal here is to modify existing models in 3D S...
# 4683    Hi we have clients who are interested in comin...
# 4788    A job description for a 3ds Max specialist typ...
# 4790    We're doing a build out for a 2000 square foot...
# 4929    Job Purpose:\nTo create highly-realistic inter...
# 5083    I am producing art apps for the meta quest mar...
# 5097    Hi! \n\nWe are a small baby toy company lookin...
# 5245    If you want a full review that will propel you...
# 5420    In need of a digital 3D model of a 20' shippin...
# 5436    Can you please convert to 3d render.\n\nThe ma...
# 5469    We need help in doing the following:\nOur clie...
# 5625    architectural facade architectural facadearchi...
# 5629    Looking for the person who can fit the standar...
# 5819    I'm looking for a 3d artist to create a series...
# 5841    I have a set of products, that I need packagin...
# 5956    Can you help me design my dream location for m...
# 6092    I plan to gut my 1986 Master Bath.  My design ...
# 6119    Looking for a low cost illustrator to create d...
# 6281    At Liberty Workspaces we design hospital and r...
# 6293    We are looking to create a CAD 3D drawing of a...
# 6355    We are looking for a phenomenal 3D rendering a...
# 6566    I need a blueprint made for a new car design t...
# 6722    3D Render our Digital Device.\n\n\nOur product...
# 6990    I have a premade module and I need to render 3...
# 7132    Make interior designs for 2bhk. In mumbai Make...
# 7176    I'm looking for a quick cheap floor plan with ...
# 7183    I have a small bedroom and I would like to red...
# 7411    We are looking for someone that creates render...
# 7428    I am looking for designs for wall art, jersey,...
# 7463    We will provide Cadfile for the kitchen design...
# 7789    We are looking for a designer to prepare conce...
# 8056    Looking for realistic 3D renders for exterior ...
# 8090    Looking for a fresh graduate or novice archite...
# 8136    I would like a few rooms to be designed. What ...
# 8165    I have a small home based business and working...
# 8218     hi i am khan and ineed a house plan . its 30 ...
# 8286    I need a 3D rendering of a bracelet design for...
# Name: Description, dtype: object
# -----------
# Android App Development Intermediate
# -----------
# 4200     Hi. I want to discuss the possibly of converti...
# 8552     App that helps upload files to google drive or...
# 8587     I need Remote Assistant AR Applications both S...
# 8589     I need auto OTP APK required, pls contact me f...
# 8659     Need a specialist to create a mock - up for An...
#                                ...
# 25919    i have a casino game mobile. i need up it to c...
# 25956    Hi I’m looking for an app developer for my bus...
# 25959    hello\n        android application upload on s...
# 26230    I need someone to build an app and I have zero...
# 26272    I bought a ready-made app from Codecanyon (rea...
# Name: Description, Length: 305, dtype: object
# -----------
# Android App Development Entry level
# -----------
# 8471     Web app using eclipse and servlet + mysql\npro...
# 8495     I need to publish my 2 games in google play co...
# 8554     We need android app publisher(need google play...
# 8556     We want to upload our app needed play console ...
# 8557     Need source code for whatsapp tracker code htt...
#                                ...
# 26079    we have an android apps to upload on google pl...
# 26111    I am looking for someone Android developer wit...
# 26118    I need find Google play console to hire\ni nee...
# 26143    i need find google play console to product my ...
# 26222    Software Requirements Document: Android Based ...
# Name: Description, Length: 95, dtype: object
# -----------
# Android App Development Expert
# -----------
# 8513     An Indian company did the project, and they co...
# 8540     We Have already our web of our crypto centrali...
# 8567     I need Android gaming app.There will be 2 game...
# 8759     We need a Android Developer who will Maintain ...
# 8775     hello\n\ni need android developer wo will uplo...
#                                ...
# 25725    hello\n\ni need android developer wo will uplo...
# 25749    hello\n\ni need android developer wo will uplo...
# 25750    hello\n\ni need android developer wo will uplo...
# 25844    We are looking for an experienced Google Play ...
# 25990    - When user long press on Power button then di...
# Name: Description, Length: 226, dtype: object
# -----------
# 3D Animation Intermediate
# -----------
# 4046    Im looking for a supplier to create my family ...
# 4050    The original logo on the website has an animat...
# 4075    We are looking for someone to help us explain ...
# 4081    Hey there\nI am looking for someone who can an...
# 4097    I want a cartoon animation hindi video which i...
#                               ...
# 8300    I'm starting a new youtube channel. I've got s...
# 8317    Hi there,\n\nI’m looking for a talent capable ...
# 8340    We want to build animation videos for one of o...
# 8343    Looking for an expert custom logo animation cr...
# 8352    Our company has recently opened a new project ...
# Name: Description, Length: 315, dtype: object
# -----------
# 3D Animation Expert
# -----------
# 4054    This animation is going to be used as a Instag...
# 4057    I am looking for a team of interior designers,...
# 4073    I need a simple (10 secs) 3D animation to be u...
# 4150    I am looking to create a full anime series tha...
# 4182    I am looking for someone to basically take a s...
#                               ...
# 8273    Hey , I have a mobile game for android and iOS...
# 8299    3D Animation Of Earth Globe Spinning With 12  ...
# 8303    Permit ready plans for a house .  This will be...
# 8312    Top 3D Graphic Designer to Design Realistic-Lo...
# 8342    We seek a highly skilled professional video ed...
# Name: Description, Length: 204, dtype: object
# -----------
# 3D Animation Entry level
# -----------
# 4070    I am currently looking for someone who is exci...
# 4129    We are in need of a 3d animator for our unity ...
# 4221    Hello! I am looking for someone to create a 15...
# 4349    In need a good 3d animator and 3d designer to ...
# 4479    My Youtube Channel Video Link :- https://youtu...
# 4602    I'm working on a documentary, i need some simp...
# 4609    Hi! We are a game studio from Brazil currently...
# 4787    I need a good 3d animator and 3d designer to m...
# 4959    Would like you to help finish a series of stud...
# 5003    Please apply only if you can do stock e-learni...
# 5124    make 3D animation of a 2D image               ...
# 5188    Need someone who can create this kind of 2nd a...
# 5256    I'm looking for a video animator to help me cr...
# 5584    Hi All,\n\nIm looking for a roblox animator us...
# 5657    I need a good 3d animator and 3d designer to m...
# 5732    Hi all,\nI'm looking for minecraft animations ...
# 5817    We are looking for an experienced and creative...
# 5839    Hello!! I am in need of a skilled 3D animator ...
# 5902    For YouTube video and Instagram reel\nAnimatio...
# 5905    For YouTube video and Instagram \nQuality vide...
# 5972    Work with 3D assets that will be provided to a...
# 6180    We are looking for a video. It'll be used in a...
# 6446    We are looking for 3d max design with basic re...
# 6816    Need a VFX artist must know about Blender, we ...
# 6979    I need someone who can draw and animate the dr...
# 7062    I have animation videos that I need to improve...
# 7464    https://www.youtube.com/watch?v=04KvcFAcGGA\nI...
# 7579    Looking for someone to create the animation fo...
# 7816    I am looking for an animated music video for t...
# 7982    I would like a splash page for my future websi...
# 8069    Hi everyone, I would like image like this to b...
# Name: Description, dtype: object
# -----------
# Python Intermediate
# -----------
# 17       I want to customize the code from https://gith...
# 53       We are consulting advertising clients on optim...
# 55       I am seeking a developer on a long-term contra...
# 130      Option strategy developer through algorithm in...
# 165      Immediately Hire and needs to complete before ...
#                                ...
# 25573    i am looking for professional who can fix my p...
# 25624    I have an old exe which was coded in Visual Ba...
# 25788    - login via outlook 365 - simple crud interfac...
# 25889    I am looking to migrate the Utils library for ...
# 34670    Coder need to convert my idea to python code i...
# Name: Description, Length: 296, dtype: object
# -----------
# Python Entry level
# -----------
# 131      create a forecast map with temperatures update...
# 467      We are looking for an AI specialist, that know...
# 680      I have an application running in Flask based o...
# 898      Please run and show these metrics: https://par...
# 1286     I am looking for a skilled and motivated Full ...
# 1765     Deliver an application that can process the da...
# 1797     Job Description: Freelance Python Developer\n\...
# 1884     I need someone to implement this https://githu...
# 1998     Hello. I want to automatize writing a weekly n...
# 2285     I want to create an application using GAN. I w...
# 2289     I want you to create a twitter bot similar to ...
# 2649     Requirement:\n\n1. Have experience and concept...
# 2800     Looking to create a people counter that runs o...
# 2861     *Need this bot to be accessed via /start on gr...
# 3022     I want to program a simple OpenAI API chatbot ...
# 3069     We are seeking a highly skilled API and WordPr...
# 3297     We would like to chat with someone who has int...
# 3391     We are an ambitious startup in the early stage...
# 3509     Hi,\n\nI would like someone to help me create ...
# 3635     Purpose:\nWe are looking for a skilled coder t...
# 3801     As an edtech company operating in the K-12 sec...
# 5400     Deliver an application that can process the da...
# 8978     We are seeking an experienced Python developer...
# 9752     Looking for a dev who wants a pretty straightf...
# 12413    Looking for an experienced developer to assist...
# 12900    Selected Candidate day-to-day responsibilities...
# 13627    create API with FastAPI register Patient\n\ncr...
# 14208    Here is my current website: www.galeriesevin.c...
# 14582    I need to create a database based on the aucti...
# 14751    I want a python module, I can import it then s...
# 17899    I have  a code in Python to be able to track c...
# 18119    I want you to build a backend for this website...
# 18477    For our group of companies Penguin Group, we a...
# 18900    We are seeking a Junior Python Developer to jo...
# 19141    GeoNode to be installed/Setup\n\nhttps://geono...
# 22877    We are looking for a skilled developer with ex...
# 22979    We have downloaded the bids and need to extend...
# 23825    Your Responsibilities\nData Engineers are expe...
# 23968    We are offering $100 to anyone who can create ...
# 24158    ignore the budget we will discuss that later B...
# 25530    Entry level ongoing support for random technic...
# Name: Description, dtype: object
# -----------
# Python Expert
# -----------
# 216      Hello I need twitter user name scrapper can yo...
# 247      I am looking for skilled DL programmer to make...
# 320      Looking to build a GPT3 based solution that is...
# 416      We are looking for someone of a team to help s...
# 525      The instruction for the project are in the att...
#                                ...
# 25132    The task is to port an existing Python 2 progr...
# 25524    Build .NET desktop application utilizing an ex...
# 25751    Looking to build a GPT3 based solution that is...
# 25869    First, I need a professional python developer....
# 31144    I need someone to create a software that allow...
# Name: Description, Length: 205, dtype: object
# -----------
# Data Scraping Intermediate
# -----------
# 29       I have a large auto parts data set in excel. I...
# 42       Final Goal: \n\n1. Find whitespaces of opportu...
# 46       I want patent data from google patent database...
# 56       PDF data scraping, parsing, extraction and ins...
# 70       Hi talents, \nI am looking for a developer to ...
#                                ...
# 41648    Hello,\n\nWe need a freelancer who will go thr...
# 43731    Require a lead generation expert to generate a...
# 44341    hi, i need someone to scrape and collect email...
# 46224    Scraping influencers from certain niches that ...
# 47755    Please fill out the spreadsheet with the names...
# Name: Description, Length: 269, dtype: object
# -----------
# Data Scraping Entry level
# -----------
# 77       Looking for someone to pull a list of all comp...
# 85       Develop and implement web scraping scripts to ...
# 86       I have a list of 190 web addresses that I need...
# 101      I need a web scraper to gather data off a stat...
# 108      Hi there! Wir sind ein Mental Health Startup a...
#                                ...
# 30062    I want someone to find a way to scrape Instagr...
# 30383    Have you ever compiled a list for public schoo...
# 30592    There is a website that publicly list the cont...
# 35588    Hi Everyone \nI Needed to get all current CxOs...
# 35823    I  need to get all current CxOs in Tunisia tha...
# Name: Description, Length: 93, dtype: object
# -----------
# Data Scraping Expert
# -----------
# 96       We are looking for someone to help us build a ...
# 127      URL WITH SAMPLE CODE: https://github.com/amira...
# 182      I am a professional magician & illusionist see...
# 226      We need someone to crawl the web for specific ...
# 242      The Data is about 800 reports divided equally ...
#                                ...
# 26475    Need an expert to build our lead gen campaign ...
# 29619    We are a cold email lead generation agency. \n...
# 36595    I have several LinkedIn scraping tools, this h...
# 37263    Data miners needed to search online and find E...
# 40204    Data miners needed to search online and find E...
# Name: Description, Length: 152, dtype: object
# -----------
# Data Analysis Expert
# -----------
# 0        Already data pooled and designed. Need to refi...
# 39       I am looking for an experienced statistician w...
# 44       We are looking for someone to help us implemen...
# 65       Ecomm business is looking for Data analysis pe...
# 66       Job Title: Web Scraper and Database Creator\n\...
#                                ...
# 4016     BM Digital (sister company of ForceField) is t...
# 11501    Create a detailed reports generated from Fresh...
# 21505    Location: Remote\n\nDuration: Minimum 6-month ...
# 35706    I need a marketing task to be done within the ...
# 42623    We are an innovative B2B SaaS startup looking ...
# Name: Description, Length: 193, dtype: object
# -----------
# Data Analysis Intermediate
# -----------
# 8        Linear regression with a possible GUI. I alrea...
# 9        I have 3 sets of data with ~60 responses each ...
# 21       huru is a health and wellness technology start...
# 26       We've been playing a bit with AI and want to t...
# 49       I need some help visualizing some data. This i...
#                                ...
# 4019     We are looking for an expert Business/Data Ana...
# 26489    I have a Microsoft 365 Personal subscription. ...
# 28375    I'm looking for a person - or a team - who cou...
# 31020    We are seeking an Influencer Marketing and Med...
# 43847    VitaDAO is a global community of longevity ent...
# Name: Description, Length: 270, dtype: object
# -----------
# Data Analysis Entry level
# -----------
# 15       Need someone who can clean my raw data in exce...
# 48       Greetings, I am a Business Intelligence expert...
# 186      Looking for a solution to track, monitor and r...
# 199      Hi, in this project - we are dealing with abst...
# 420      I need help in Pelican Stores Data Analysis an...
# 529      I have an excel and sql assignment to be compl...
# 550      The final deliverable will be a 15-page paper ...
# 676      Hello there,\n\nAny business Analyst currently...
# 904      Some excel spreadsheet need to be transferred ...
# 1117     The job involves using data analytics techniqu...
# 1131     - I have sales data stored in excel sheets and...
# 1197     Run frequencies for a mid-size spreadsheet, an...
# 1264     This task requires one to use R/Python or any ...
# 1514     Your job will be to support the growth of Orte...
# 1696     Statistical analysis in R for a social science...
# 1934     I need someone to analyze data using python fo...
# 2012     I want to hire an excel expert who can analyse...
# 2026     Will do a rainfall analysis one of my project\...
# 2040     Data analyst responsibilities include conducti...
# 2351     Role: Data Analyst (REMOTE Part time - eventua...
# 2502     You are required to classify three types of wi...
# 2642     I need excel files of data be analysed for der...
# 2644     Looking for a reliable, detail-oriented person...
# 2697     We use Geckoboard to display company metrics. ...
# 3206     I want data scientist in sri lanka to do Basic...
# 3269     3) Program a game with the following rules: Th...
# 3351     evaluate whether an educational intervention, ...
# 3454     $60-$80/hr\nWe are looking for an eager, profe...
# 3549     I Need Data Analytics Expert. I Need Mobile Sh...
# 3807     You/ will be meeting internally to determine/ ...
# 3846     Data Engineers develop modern data architectur...
# 43771    1. 对知乎和微信平台非常熟悉 2. 会写简单的公众号 3. 主动学习 4. organiz...
# Name: Description, dtype: object
# -----------
# Search Engine Marketing Expert
# -----------
# 26321    Hello!\n\nI have an ecommerce and would like a...
# 26401    Looking for Baidu expert to get us on Baidu. \...
# 26464    We are looking for an experienced Google Ads C...
# 26722    Hey there!\n\nI'm looking for a senior-level f...
# 26885    Must be readily available during daytime hours...
#                                ...
# 47487    PASSIONATE ABOUT DIGITAL MARKETING & ALL THING...
# 47610    Looking for a proficient GOOGLE AD expert that...
# 47645    We are a successful and experienced education ...
# 47757    Hello!\n\nHere's the task:\n1) To select keywo...
# 47792    We are looking for an expert Google Ads manage...
# Name: Description, Length: 209, dtype: object
# -----------
# Search Engine Marketing Intermediate
# -----------
# 26366    Hello and welcome. Thank you for your interest...
# 26387    The job is for a website that sells sleep apne...
# 26488    We are a motorcycle rental company based in Ha...
# 26607    I need 8-10 questions answered related to Goog...
# 26849    We're an ecommerce brand in India looking to s...
#                                ...
# 47494    We are looking for an AdWords expert for 2 com...
# 47597    I am a physician working as a consultant onlin...
# 47644    Looking for a person well versed in SEO and Go...
# 47702    Hello!\n\nI am looking for a go-to researcher ...
# 47708    Create an online marketing strategy for a cons...
# Name: Description, Length: 260, dtype: object
# -----------
# Search Engine Marketing Entry level
# -----------
# 27071    Im Mitch from South Africa and i'm just starti...
# 27436    We are seeking an experienced and detail-orien...
# 27693    Small size company in the tourism & hospitalit...
# 28607    Hi. I'm looking for a talented and creative di...
# 34373    I have big brand in USA i need who can mange P...
# 36849    I'm looking bing ads expert person,\n\nI'm fac...
# 36853    We need experience someone who is an expert on...
# 39498    Looking for someone who has proving track reco...
# 40680    Need 5 Guest posting Sites minimum traffic 5k ...
# 46659    i'm looking bing ads expert person,\n\ni'm fac...
# 47090    Looking for help with setting up Google ad cam...
# Name: Description, dtype: object
# -----------
# Sales & Marketing Intermediate
# -----------
# 6659     I am looking for some who can hunt clients (le...
# 26463    We are a family-owned restaurant that had an i...
# 26675    I have 3 current product flyers in pdf; I don'...
# 26953    Payment per client (monthly) Experience with I...
# 26966    We are seeking a motivated and experienced Lea...
#                                ...
# 47454    Identify and target high-potential prospects i...
# 47463    we need a business development officer for our...
# 47507    I need leads for my software company. Not just...
# 47589    We are a Company selling Brand products on Ama...
# 47784    Offer Description\n\nInterview the SEN candida...
# Name: Description, Length: 246, dtype: object
# -----------
# Sales & Marketing Entry level
# -----------
# 7867     Need leads for interior design and 3d visualiz...
# 9333     Türkiye’de kurulan ve üretimlerini Türkiye’de ...
# 26898    Skills Required:\n*Any University Graduates \n...
# 26926    start a business for me and run it as long as ...
# 27280    Need someone to join our team as a sales coach...
# 27339    Job Description\n\nPosition: Sales and Reserva...
# 27351    I'm searching for an assistant to help manage ...
# 28070    The work:\nClose deals for my Agency.\n\nHow?\...
# 28921    Este proyecto busca contratar a captadores de ...
# 30003    What profile we are looking for: \n\n- Native ...
# 32180    We're currently seeking a Zillow ad manager to...
# 32299    Job opening – Account & Project Manager – Remo...
# 32426    We are a UK-based digital agency looking for a...
# 33326    Hello!\n\nI am looking to hire a salesperson t...
# 33516    Criação de fluxo de vendas e inbound marketing...
# 35126    There are a total of 12 job openings, consisti...
# 35475    This is a 1099 completely commission-based rol...
# 36966    see this is a marketing job u need to get peop...
# 37589    As someone who's been in affiIiate marketIng f...
# 38496    Game developing company exploring sales talent...
# 38970    Make real estate flyer better\n\n\n\nMake the ...
# 39526    Job Title: Sales & Marketing Associate\n\nWe a...
# 39569    Hey, I'm looking for someone to chat with my s...
# 40478    i want 50 new emails with passwords on gmail, ...
# 40495    Hey there!!!\n\nI am looking for experienced c...
# 40768    I have a trading strategy of Indian Stock Mark...
# 40791    Hello \nI am looking for someone who can get s...
# 41112    At Daphne's Store, we believe that everyone de...
# 42216    We are a growing e-commerce company looking fo...
# 42562    Calling local business that have 5 or more emp...
# 42796    We are seeking a highly motivated and detail-o...
# 43602    Help to put together a sales team for Brazilia...
# 43661    \nGet ready to blast off on an exciting journe...
# 43993    Looking for an Operations Manager to oversee a...
# 44217    We are looking for a Catawiki expert, with pro...
# 44241    I will need help with the following:\n- Findin...
# 44440    I need 1000 email sign-ups for my iPhone 14 Of...
# 45155    Hi we are handmade manufacturer for woman fash...
# 45219    We are looking for a Graphic Designer who can ...
# 45900    I am a small business owner making handmade pr...
# 46485    Game developing company exploring sales talent...
# 46518    European Business Development –JD\n\n\nJob Loc...
# 47488    We are a marketing Agency and we are looking f...
# 47804    Are you looking for a position of responsibili...
# Name: Description, dtype: object
# -----------
# Sales & Marketing Expert
# -----------
# 9391     Need a knowledgeable person to manage and crea...
# 26468    U.S Based Mortgage Brokerage with 20 years of ...
# 26641    I will be doing graphic promo work for social ...
# 26688    I want advice about hiring salespeople to find...
# 26711    We're seeking a professional recruiters to hel...
#                                ...
# 47228    **About us**\nWe are a fund that ensures our c...
# 47261    We are seeking a full-time Sales and Admin Ass...
# 47363    We are looking for a Sales Coach/Consultant to...
# 47820    We are looking for an expert in growing a US-b...
# 47828    Email marketing expert for a shopify store cen...
# Name: Description, Length: 173, dtype: object
# -----------
# Influencer Marketing Expert
# -----------
# 15077    Looking for a marketing expert that specialize...
# 26440    We are currently seeking influencer marketing ...
# 26792    Hi,\nWe are looking to engagne a digital marke...
# 27151    Looking to hire someone to help me get more fo...
# 27236    We want to partner up with an influencer that ...
#                                ...
# 46845    We're looking for a highly motivated and creat...
# 47294    Professional services company seeks super crea...
# 47412    About our company:\n\nThrough ShelisaB Inc. an...
# 47658    I'm looking for someone personable, has a fast...
# 47781    hey Fam, we are looking for individual influen...
# Name: Description, Length: 140, dtype: object
# -----------
# Influencer Marketing Intermediate
# -----------
# 26391    I have a shopify store selling shirts and hood...
# 26392    I have a shopify store selling shirts and hood...
# 26469    Looking for a Freelancer in Influencer Marketi...
# 26507    Voor DailyChef (@dailychefeu) zijn wij op zoek...
# 26638    We are seeking an experienced marketer to help...
#                                ...
# 47263    Hello,\n\nwe're looking for a Social Media Acc...
# 47319    I am looking for a FREELANCER, not an agency, ...
# 47531    We have a new SaaS startup in the influencer m...
# 47573    I am a micro influencer in the True Crime comm...
# 47822    I have produced three feature length movies an...
# Name: Description, Length: 268, dtype: object
# -----------
# Influencer Marketing Entry level
# -----------
# 26636    Shorterm rental marketing, and manager. Market...
# 26841    You must be a fan of comic books, comic book m...
# 26999    Share my ebook on a Instagram, Facebook, Twitt...
# 27039    We're developing a community dedicated to anim...
# 27464    seeking experience individual for ETSY PLATFOR...
# 28357    Our company is looking for someone who can han...
# 28942    We are looking for a talented and creative pre...
# 29955    Objectives: Content and impression\n1. Create ...
# 30911    stated a business priority one is funding this...
# 31063    Hello, We are a Digital Marketing company and ...
# 32063    I am looking for content creators for my team....
# 32066    Hey everyone!\n\nWe are looking for female con...
# 33138    I am looking for content creators for my team....
# 34343    looking for SEO and Digital Marketing, website...
# 35200    We are a newly established social media compan...
# 35746    Need someone to search the right kind of influ...
# 36258    We need INTERESTING people with SPICY/CONTROVE...
# 36679    SCOPE OF WORK:\nI'm looking for content creato...
# 36863    We are a growing beachwear company looking for...
# 37023    - manage our presence in Facebook, LinkedIn, T...
# 37210    Hello I work in finance and I am looking to cr...
# 37293    We're a digital marketing agency that wants to...
# 39603    Listen to the dialogue online and make note of...
# 39633    I have created an independent animated movie. ...
# 40926    I am looking for an experienced social media m...
# 41297    I have created an independent animated movie. ...
# 42115    100 Philippines influencers from Facebook\n\nM...
# 42328    Show off your professional skills to explain w...
# 42535    Dear all,\n\nWe are a technology company, JunA...
# 42649    Sourcing large volume of KOLs in for Brazilian...
# 44099    We as a company are looking for highly talente...
# 44272    Hello and welcome! We're a software start-up l...
# 44602    Hey there! We are PerCal Naturals, we provide ...
# 45307    Hello everyone, \nI am a beginner youtuber. Cu...
# 45334    Im looking for a manager that can help me take...
# 47009    We are looking to bring on board a social medi...
# 47366    Part Time Side-Hustle: Social Creators Wanted\...
# 47607    This will be a FAST and EASY job that will ear...
# 47721    Ik ben op zoek naar een social media manager v...
# Name: Description, dtype: object
# -----------
# Data Science Expert
# -----------
# 7       Looking for freelancer to implement following ...
# 60      Hop is a Data Science and Analytics talent eng...
# 83      Hi there, \n\nWe're working on automating mort...
# 105     Job Title: Natural Language Processing Coach\n...
# 162     * Develop and implement reusable architecture ...
#                               ...
# 3884    Objective:\n\nThe objective of this project is...
# 3908    Expert Python(and PineScript) / Machine Learni...
# 3936    We are writing an introductory Causal Inferenc...
# 4002    We have a large number of items, nodes and ver...
# 4020    Looking for data scientist expert who can anal...
# Name: Description, Length: 152, dtype: object
# -----------
# Data Science Intermediate
# -----------
# 47       Our company is building a platform where brand...
# 50       I currently have a website that a developer di...
# 81       Looking for an experienced GIS analyst to assi...
# 87       Looking for someone who can help me with data ...
# 103      Looking for an experienced and talented person...
#                                ...
# 4015     # What is DataWars #\nDataWars is a Data Scien...
# 4017     I need to write an article to about one hot en...
# 16682    Looking for an experienced GIS analyst to assi...
# 25428    Polonya tutkiye arasi vize tarihi almak icin w...
# 47320    We have a number of Google Sheets that we use ...
# Name: Description, Length: 261, dtype: object
# -----------
# Data Science Entry level
# -----------
# 133     From the perspective of actuarial pricing mode...
# 180     To support on Data Science Academic guidance\n...
# 210     I have very limited coding experience, i would...
# 399     **The Position**\n\nThis position falls into t...
# 413     - Has experience gathering a panel of consumer...
# 586     Need an assistant\nto search for conference in...
# 632     We have dozens of python projects because we w...
# 646     We have dozens of python projects because we w...
# 810     Hello, \n\nI need to consult with an ML profes...
# 859     I was looking for a mathematician or physicist...
# 926     I have already Created a model BQ ML model in ...
# 1094    A simple Novel Smart DDoS attack prevention sy...
# 1106    As a language model developed by OpenAI, I do ...
# 1361    Looking for experienced web developers, that h...
# 1366    Looking for experienced web developers, that h...
# 1719    Hi,\n\nI would like to create a web-based tool...
# 1780    First, the improvement of the existing Matlab ...
# 1968    I am learning for \ndata science . Need to get...
# 2049    Demonstrated ability to execute effectively in...
# 2066    Hello,\n\nWe need experience python and ML dev...
# 2640    Based on exports from a system you will get CS...
# 2676    We are looking for a writer to write well-rese...
# 2891    Job Title: Full-Stack Developer (Remote)\n\nAb...
# 2916    Please check the attached image for the questi...
# 2929    Need an assistant\nto search for conference in...
# 3228    We are a growing consulting firm that speciali...
# 3247    Hello! \n\nI'm looking for a college student w...
# 3329    We are looking for an experienced and self-mot...
# 3370    Create a transparent watermark for images (jpg...
# 3587    I want tobuild machile learning model to class...
# 3713    I need to upload the data from an Excel spread...
# Name: Description, dtype: object
# -----------
# B2B Marketing Entry level
# -----------
# 26328    Achieve your revenue-based quota by selling re...
# 26698    # Appointment setter/ Cold Caller\n\nAppointme...
# 27384    Achieve your revenue-based quota by selling re...
# 28317    We are looking for a seller.\n\nThe product is...
# 28519    Looking for someone with a zoominfo and linked...
# 28965    Achieve your revenue-based quota by selling re...
# 29581    I need someone to get me contacts with high DR...
# 29726    I am looking for some expert to find leads in ...
# 29823    Need a list of 1000 contacts in  that have the...
# 30136    Write all the copy of the website. the company...
# 31067    We are looking for an individual who is biling...
# 31723    Job Description:\n\nAs a Commission-Based Appo...
# 31925    We will provide a list of leads weekly, all yo...
# 32907    i need someone to close clients for my web dev...
# 34467    Looking some expert in cold calling for publis...
# 35233    Luxe Home Offer, LLC is Hiring for a Full-Time...
# 37183    Hi there,\n\nI am the owner of a lead gen agen...
# 37637    We are seeking a highly motivated Appointment ...
# 38261    The candidate for this position will excel at ...
# 38707    Seeking an Account Executive to join our growi...
# 38953    Introduce real estate agents to a new service ...
# 39772    We are a company located in Turkey, havimg als...
# 39943    *     Maintaining fruitful relationships with ...
# 40124    CNPP Business Advocate \n \nThe US Pan Asian A...
# 40610    We are a software company that created a softw...
# 41844    Hey guys, we are looking for a person to do th...
# 42949    Achieve your revenue-based quota by selling re...
# 43473    Looking for a representative who can market ou...
# 45069    JOB TITLE: COLD CALLER\n\nLocation: Remote\n\n...
# 45301    Hi,\n\nI have a video production company in Sa...
# 45641    Hi \n\nI own a marketing company that assists ...
# 46239    Work includes making outbound calls, handling ...
# 46499    Remote working - leads conversion to fee payin...
# 46898    Sales Associate at ProdigyNext:\n\nProdigyNext...
# 47513    The onboarding process for sales and business ...
# Name: Description, dtype: object
# -----------
# B2B Marketing Intermediate
# -----------
# 26398    Looking for a Freelance Sales Manager based in...
# 26465    I run a highly technical newsletter (WeeklyRob...
# 26561    I am seeking a dynamic and motivated sales rep...
# 26614    I own a marketing agency that specializes in d...
# 26730    We are a small web design agency based in Sing...
#                                ...
# 47678    An email marketing agency needs someone with a...
# 47689    The Sales Development Representative (SDR) is ...
# 47725    We need the design for a double-sided 10x 10 t...
# 47813    Hope you're doing great and healthy.\n\nWe are...
# 47835    *Need to visit retailers/stores *Explain the b...
# Name: Description, Length: 247, dtype: object
# -----------
# B2B Marketing Expert
# -----------
# 26727    Need an Appointment Setter based in US who can...
# 26800    Mahmoud skills scope is doing End to End solut...
# 26957    We're a email outreach agency based in Austral...
# 27013    #JOBOFFER #HIRING 🔗\n\n\nMy Company/Agency is ...
# 27035    I’m currently looking for a LinkedIn Outreach ...
#                                ...
# 46996    Hi,\nWe manufacture and import a unique line o...
# 47275    Thank you for your interest! Please see the be...
# 47306    Looking for someone to write/create a converti...
# 47401    Looking for someone to cold call businesses, a...
# 47524    Seo to be done for 10 to 20 keywords \nTarget ...
# Name: Description, Length: 140, dtype: object
# -----------
# Lead Generation Entry level
# -----------
# 958      Need to enlist a few specialists to find compu...
# 3526     I’m looking for some help in using the tech of...
# 11774    B2B Lead Generation Requirements\nWe need some...
# 12034    We are a professional Online Fitness Coaching ...
# 26412    Looking For Lead Generation Expert, Who Can Ma...
#                                ...
# 44936    collect 1000 preschool / daycare emails (schoo...
# 45717    I need 5 hours of work done today.  You will b...
# 46215    •\tGenerates sales leads through Company–spons...
# 46950    I am looking for lead generation and sales lea...
# 47562    This is a short-term lead generation project f...
# Name: Description, Length: 83, dtype: object
# -----------
# Lead Generation Expert
# -----------
# 1093     A renowned Insurance brand who already ranks o...
# 26429    Job Description:\nWe are a solar company looki...
# 26608    I need a Media Buyer for my Social media marke...
# 27014    Looking to partner with a LinkedIn expert who ...
# 27064    Our Edutech company is seeking a team of exper...
#                                ...
# 47066    We are needing people that are LOYAL, DEDICATE...
# 47234    Real estate investor/wholesaler in the greater...
# 47564    I'm looking for someone that can help scrape l...
# 47772    Looking of email address and LinkedIn account ...
# 47791    Attention All Expert ManyChat Freelancers!\n\n...
# Name: Description, Length: 140, dtype: object
# -----------
# Lead Generation Intermediate
# -----------
# 9617     Description: Looking for a lead generation exp...
# 20072    I operate a web design and mobile app developm...
# 22484    Set up a Google Cloud projec create a Google C...
# 26460    Looking for an experienced Upwork bidder. Some...
# 26630    We are a software development agency mainly fo...
#                                ...
# 47334    need a freelancer who collect 50 leads of priv...
# 47345    I have 5400 or so leads within HubSpot. I have...
# 47459    Looking for someone to help us set B2B sales c...
# 47472    Need someone who has experience working on Lin...
# 47806    I need a Business Development Manager to bid o...
# Name: Description, Length: 199, dtype: object

# %%
docs = full_df["Description"].tolist()

# %%
doc_array = []


for index in full_df_index:
    for ex_level in full_df[full_df["Category_1"] == index]["EX_level_demand"].unique():
        print("-----------")
        print(index, ex_level)
        print("-----------")
        condition1 = full_df["Category_1"] == index
        condition2 = full_df["EX_level_demand"] == ex_level
        docs = full_df[condition1 & condition2]["Description"].tolist()
        doc_array.append(docs)
# Out:
# -----------
# Web Development Expert
# -----------
# -----------
# Web Development Intermediate
# -----------
# -----------
# Web Development Entry level
# -----------
# -----------
# Social Media Marketing Intermediate
# -----------
# -----------
# Social Media Marketing Expert
# -----------
# -----------
# Social Media Marketing Entry level
# -----------
# -----------
# Marketing Strategy Intermediate
# -----------
# -----------
# Marketing Strategy Expert
# -----------
# -----------
# Marketing Strategy Entry level
# -----------
# -----------
# 3D Modeling Expert
# -----------
# -----------
# 3D Modeling Entry level
# -----------
# -----------
# 3D Modeling Intermediate
# -----------
# -----------
# Email Marketing Expert
# -----------
# -----------
# Email Marketing Intermediate
# -----------
# -----------
# Email Marketing Entry level
# -----------
# -----------
# Mobile App Development Intermediate
# -----------
# -----------
# Mobile App Development Expert
# -----------
# -----------
# Mobile App Development Entry level
# -----------
# -----------
# 3D Design Expert
# -----------
# -----------
# 3D Design Intermediate
# -----------
# -----------
# 3D Design Entry level
# -----------
# -----------
# Market Research Intermediate
# -----------
# -----------
# Market Research Expert
# -----------
# -----------
# Market Research Entry level
# -----------
# -----------
# 3D Rendering Intermediate
# -----------
# -----------
# 3D Rendering Expert
# -----------
# -----------
# 3D Rendering Entry level
# -----------
# -----------
# Android App Development Intermediate
# -----------
# -----------
# Android App Development Entry level
# -----------
# -----------
# Android App Development Expert
# -----------
# -----------
# 3D Animation Intermediate
# -----------
# -----------
# 3D Animation Expert
# -----------
# -----------
# 3D Animation Entry level
# -----------
# -----------
# Python Intermediate
# -----------
# -----------
# Python Entry level
# -----------
# -----------
# Python Expert
# -----------
# -----------
# Data Scraping Intermediate
# -----------
# -----------
# Data Scraping Entry level
# -----------
# -----------
# Data Scraping Expert
# -----------
# -----------
# Data Analysis Expert
# -----------
# -----------
# Data Analysis Intermediate
# -----------
# -----------
# Data Analysis Entry level
# -----------
# -----------
# Search Engine Marketing Expert
# -----------
# -----------
# Search Engine Marketing Intermediate
# -----------
# -----------
# Search Engine Marketing Entry level
# -----------
# -----------
# Sales & Marketing Intermediate
# -----------
# -----------
# Sales & Marketing Entry level
# -----------
# -----------
# Sales & Marketing Expert
# -----------
# -----------
# Influencer Marketing Expert
# -----------
# -----------
# Influencer Marketing Intermediate
# -----------
# -----------
# Influencer Marketing Entry level
# -----------
# -----------
# Data Science Expert
# -----------
# -----------
# Data Science Intermediate
# -----------
# -----------
# Data Science Entry level
# -----------
# -----------
# B2B Marketing Entry level
# -----------
# -----------
# B2B Marketing Intermediate
# -----------
# -----------
# B2B Marketing Expert
# -----------
# -----------
# Lead Generation Entry level
# -----------
# -----------
# Lead Generation Expert
# -----------
# -----------
# Lead Generation Intermediate
# -----------

# %%
doc_array = []


for index in full_df_index:
    print(index)
# Out:
# Web Development
# Social Media Marketing
# Marketing Strategy
# 3D Modeling
# Email Marketing
# Mobile App Development
# 3D Design
# Market Research
# 3D Rendering
# Android App Development
# 3D Animation
# Python
# Data Scraping
# Data Analysis
# Search Engine Marketing
# Sales & Marketing
# Influencer Marketing
# Data Science
# B2B Marketing
# Lead Generation

# %%
small_doc_array = []


for index in full_df_index:
  condition1 = full_df["Category_1"] == index
  docs = full_df[condition1]["Description"].tolist()
  small_doc_array.append(docs)

# %%
len(small_doc_array)
# Out:
# 20

# %%
full_df_index[3]
# Out:
# '3D Modeling'

# %%
for i in range(0,20):
  curr_index = i
  topics, probs = topic_model_yes_vec.fit_transform(small_doc_array[curr_index]) # yes vec
  topic_model_yes_vec.save(f"/content/drive/MyDrive/!AAA/topic_model_save/{full_df_index[curr_index]}", serialization="safetensors", save_ctfidf=True)
  print(full_df_index[curr_index])
# Out:
# Web Development
# Social Media Marketing
# Marketing Strategy
# 3D Modeling
# Email Marketing
# Mobile App Development
# 3D Design
# Market Research
# 3D Rendering
# Android App Development
# 3D Animation
# Python
# Data Scraping
# Data Analysis
# Search Engine Marketing
# Sales & Marketing
# Influencer Marketing
# Data Science
# B2B Marketing
# Lead Generation

# %% [markdown]
# training

# %%
curr_index = 19

# %%
full_df_index[curr_index]
# Out:
# 'Lead Generation'

# %%
topics, probs = topic_model_yes_vec.fit_transform(small_doc_array[curr_index]) # yes vec

# %%
topics, probs = topic_model.fit_transform(small_doc_array[curr_index]) # no vec

# %%
topic_model_yes_vec.save(f"/content/drive/MyDrive/!AAA/topic_model_save/{full_df_index[curr_index]}", serialization="safetensors", save_ctfidf=True)

# %%
curr_index = 0
print(full_df_index[curr_index])

loaded_model = BERTopic.load(f"/content/drive/MyDrive/!AAA/topic_model_save/{full_df_index[curr_index]}")
# Out:
# Web Development

# %%
print(full_df_index[curr_index])
loaded_model.visualize_barchart() # call loaded model
# Out:
# Web Development
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="25832f71-f92f-47a6-a2be-e13953a2ad14" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25832f71-f92f-47a6-a2be-e13953a2ad14")) {                    Plotly.newPlot(                        "25832f71-f92f-47a6-a2be-e13953a2ad14",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.012249014837018398,0.012838677724811958,0.014788727399123113,0.026787992405061183,0.0549085768386535],"y":["theme  ","products  ","product  ","store  ","shopify  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.013280022163934905,0.01483555314028379,0.02224202880119941,0.04170931408186662,0.05574673802325577],"y":["developer  ","experience  ","node  ","js  ","react  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.019356915151929985,0.01978763799994413,0.021611849545965345,0.02504865219136459,0.03759665930700209],"y":["developer  ","web  ","website  ","looking  ","designer  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.013483121280210121,0.01491852005017968,0.024230670961740114,0.03555245883800451,0.06220699390917714],"y":["clickfunnels  ","funnel  ","pages  ","page  ","landing  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.011251130478886255,0.011858856523320773,0.012275850955229739,0.01611683598498072,0.103903951820029],"y":["websites  ","experience  ","website  ","design  ","webflow  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.02030652127681652,0.021006756010163437,0.02168667079933938,0.025501533870775778,0.031412225438821974],"y":["content  ","new  ","site  ","updated  ","update  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.010979719834786834,0.011532697321512629,0.017302581698398368,0.0202283359823738,0.10088152766376698],"y":["analytics  ","page  ","cloudbeds  ","website  ","wix  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.02355431468816705,0.025241073294607494,0.025455597888246292,0.025781780628472546,0.031294058973654545],"y":["students  ","courses  ","lms  ","course  ","learning  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333333333 ...

# %%
topic_model_yes_vec.get_topic_info()
# Out:
#    Topic  Count                                     Name  \
# 0     -1    169               -1_leads_looking_lead_need
# 1      0     56       0_sales_clients_business_marketing
# 2      1     53               1_list_email_location_need
# 3      2     36            2_linkedin_job_leads_services
# 4      3     34              3_cold_calling_leads_estate
# 5      4     27                4_lead_generation_need_ad
# 6      5     20             5_company_address_need_leads
# 7      6     15  6_appointments_appointment_dentist_work
# 8      7     12                   7_long_owner_lead_term
#
#                                       Representation  \
# 0  [leads, looking, lead, need, email, work, sale...
# 1  [sales, clients, business, marketing, team, ne...
# 2  [list, email, location, need, business, addres...
# 3  [linkedin, job, leads, services, looking, mess...
# 4  [cold, calling, leads, estate, looking, real, ...
# 5  [lead, generation, need, ad, looking, experien...
# 6  [company, address, need, leads, companies, inf...
# 7  [appointments, appointment, dentist, work, loo...
# 8  [long, owner, lead, term, google, good, sourci...
#
#                                  Representative_Docs
# 0  [As a Cold Email/Call Representative for Marke...
# 1  [Job Title: Commission-Based Sales Representat...
# 2  [Hi! I am looking for someone who build a list...
# 3  [Job Title: Outreach Campaign Manager/Copywrit...
# 4  [Company Overview:\n\nWe are a fast-growing te...
# 5  [Hi!\n\nI’m a freelance Motion Designer, illus...
# 6  [Hello ! \n\nI would like to make an offer for...
# 7  [Title: Freelance Opportunity: Setup Appointme...
# 8  [Serious inquiries only*** - Specialized marke...

# %%
topic_model_yes_vec.get_topic(topic=0)
# Out:
# [('react', 0.06039370381996736),
#  ('js', 0.04509645315296145),
#  ('node', 0.023456850431196757),
#  ('experience', 0.014881210278274501),
#  ('app', 0.014081471663291134),
#  ('developer', 0.0137656983702417),
#  ('strong', 0.013094885979858856),
#  ('development', 0.01298937037947245),
#  ('team', 0.012553564860609387),
#  ('using', 0.01244423274348741)]

# %%
topic_model_yes_vec.get_representative_docs(27)

# %%
topic_model_yes_vec.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e7936de5-fb46-4dc9-823f-39f6ed4186dc" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7936de5-fb46-4dc9-823f-39f6ed4186dc")) {                    Plotly.newPlot(                        "e7936de5-fb46-4dc9-823f-39f6ed4186dc",                        [{"customdata":[[0,"react | js | node | experience | app",167],[1,"shopify | product | store | theme | products",136],[2,"webflow | design | website | experience | websites",110],[3,"wix | website | page | design | need",99],[4,"landing | page | pages | devex | funnel",95],[5,"update | updated | new | site | content",90],[6,"learning | lms | course | courses | student",84],[7,"responsive | mobile | devices | desktop | version",84],[8,"speed | slow | loading | pagespeed | score",81],[9,"ai | chatbot | chatgpt | chat | gpt",79],[10,"laravel | php | mysql | project | vue",77],[11,"ecommerce | website | pixel | commerce | online",76],[12,"payment | gateway | stripe | card | account",74],[13,"shopify | store | liquid | experience | apps",69],[14,"designer | web | looking | design | website",67],[15,"wordpress | team | experience | plugins | development",62],[16,"squarespace | website | ghostwriting | look | built",55],[17,"migrate | old | new | domain | wordpress",52],[18,"wordpress | updates | sites | updating | issues",51],[19,"elementor | using | wordpress | sitepagafacil | configure",50],[20,"python | django | application | flask | web",50],[21,"logo | company | page | services | construction",47],[22,"theme | wordpress | html | customize | need",43],[23,"app | ios | apps | salesforce | android",42],[24,"wordpress | website | basic | create | want",41],[25,"booking | calendar | tickets | seats | events",41],[26,"portfolio | pixpa | freelancer | looking | websites",39],[27,"video | videos | upload | audio | thumbnail",39],[28,"excel | sheet | data | software | file",38],[29,"pages | page | homepage | layout | design",37],[30,"figma | design | responsive | id | file",36],[31,"cod | italy | meaning | searching | especially",34],[32,"estate | real | property | broker | properties",33],[33,"php | mysql | developer | codeigniter | looking",33],[34,"bubble | io | app | platform | ckeditor",33],[35,"nft | defi | defigram | nfts | wallet",32],[36,"error | issue | fix | server | showing",32],[37,"shipping | product | woocommerce | customer | woo",30],[38,"la | en | et | que | je",29],[39,"clone | cloned | need | original | site",28],[40,"calculator | bid | emailmarketing | price | revenue",28],[41,"shopify | store | applicants | fix | developer",27],[42,"casino | game | sports | betting | guests",26],[43,"book | pdf | accomplish | buyer | email",25],[44,"aws | lambda | s3 | python | amazon",25],[45,"technical | web | applications | programming | development",24],[46,"php | version | update | upgrade | duckhams",23],[47,"hours | wordpress | lando | monthly | work",22],[48,"stack | occasional | preferred | college | position",22],[49,"end | software | applications | stack | programming",20],[50,"webflow | figma | d1 | phase | d0",20],[51,"cloudbeds | dashboard | data | analytics | booking",20],[52,"mvp | posts | downvote | advertiser | upvote",20],[53,"freshly | business | school | dsd | need",19],[54,"donations | donors | event | events | hipaa",18],[55,"partner | agency | nonprofits | silent | websites",17],[56,"mediator | mediatebc | meta | website | organization",16],[57,"points | defined | visual | usability | html",16],[58,"description | job | section | clicking | detailed",16],[59,"design | web | designs | functional | team",15],[60,"food | pos | restaurant | allows | stock",15],[61,"software | programs | processes | workflows | code",14],[62,"form | email | inbox | forms | conta ...

# %%
df = pd.DataFrame({'topic': topics, 'document': docs})
df.loc[df["topic"] == 27]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-093e63739a7a> in <cell line: 1>()
# ----> 1 df = pd.DataFrame({'topic': topics, 'document': docs})
#       2 df.loc[df["topic"] == 27]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     662         elif isinstance(data, dict):
#     663             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665         elif isinstance(data, ma.MaskedArray):
#     666             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     491             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     492
# --> 493     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     494
#     495
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         # figure out the index, if necessary
#     117         if index is None:
# --> 118             index = _extract_index(arrays)
#     119         else:
#     120             index = ensure_index(index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     664             lengths = list(set(raw_lengths))
#     665             if len(lengths) > 1:
# --> 666                 raise ValueError("All arrays must be of the same length")
#     667
#     668             if have_dicts:
#
# ValueError: All arrays must be of the same length
